# %% [markdown]
# # FIFA Prediction
# **Objective**: Dev ML model to predict First, Second and Third Place for 2018 FIFA worldcup<br>
# **Features**: Kaggle historical data for past matches including friendly games, Eloranking by country<br>
# **Purpose**: Submissions for DBS internal competition (Due 25/06/2018)

# %% [markdown]
# ## 1) Data prep
# Process the history kaggle data from results.csv (1930 onwards due to limitation of elorating data)<br>
# Possible integration with elorating (Used custom javascript to crawl data from https://www.eloratings.net/)

# %%
# import libraries for data manipulation
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# example making new class predictions for a classification problem
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout, TimeDistributed, AveragePooling1D, Flatten
from keras.utils import to_categorical
from keras.optimizers import Adam, RMSprop

# back up model graph
from keras.models import load_model

# using sklearn to have 1 liner cross validation
from sklearn.model_selection import train_test_split
# Out:
# c:\users\poryee\appdata\local\programs\python\python35\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
# Read .csv files from kaggle
results = pd.read_csv('datasets/results.csv')

# %%
# observe results
results.head()
# Out:
#          date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England           0           0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland           4           2   Friendly   London
# 2  1874-03-07  Scotland   England           2           1   Friendly  Glasgow
# 3  1875-03-06   England  Scotland           2           2   Friendly   London
# 4  1876-03-04  Scotland   England           3           0   Friendly  Glasgow
#
#     country
# 0  Scotland
# 1   England
# 2  Scotland
# 3   England
# 4  Scotland

# %% [markdown]
# ##### Through the exploration of data we need to find the absolute difference in score and the winning team<br>Append the corresponding results to the newly created columns [wining_team]<br>And finally, keep data of teams that make it to the group stage while dropping the rest

# %%
# Adding new column for winner of each match
winner = []
for i in range(len(results['home_team'])):
    if results['home_score'][i] > results['away_score'][i]:
        winner.append(results['home_team'][i])
    elif results['home_score'][i] < results['away_score'][i]:
        winner.append(results['away_team'][i])
    else:
        winner.append('Tie')
results['winning_team'] = winner

# Adding new column for goal difference in matches
results['goal_difference'] = np.absolute(results['home_score'] - results['away_score'])

# view new sample header
results.head()
# Out:
#          date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England           0           0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland           4           2   Friendly   London
# 2  1874-03-07  Scotland   England           2           1   Friendly  Glasgow
# 3  1875-03-06   England  Scotland           2           2   Friendly   London
# 4  1876-03-04  Scotland   England           3           0   Friendly  Glasgow
#
#     country winning_team  goal_difference
# 0  Scotland          Tie                0
# 1   England      England                2
# 2  Scotland     Scotland                1
# 3   England          Tie                0
# 4  Scotland     Scotland                3

# %%
# scope current worldcup team qualifing teams
wc_teams = ['Australia', ' Iran', 'Japan', 'Korea Republic', 
            'Saudi Arabia', 'Egypt', 'Morocco', 'Nigeria', 
            'Senegal', 'Tunisia', 'Costa Rica', 'Mexico', 
            'Panama', 'Argentina', 'Brazil', 'Colombia', 
            'Peru', 'Uruguay', 'Belgium', 'Croatia', 
            'Denmark', 'England', 'France', 'Germany', 
            'Iceland', 'Poland', 'Portugal', 'Russia', 
            'Serbia', 'Spain', 'Sweden', 'Switzerland']

# Filter the 'results' dataframe to show only teams in this years' world cup, from 1930 onwards
# we only care about teams that qualify
df_teams_home = results[results['home_team'].isin(wc_teams)]
df_teams_away = results[results['away_team'].isin(wc_teams)]
df_teams = pd.concat((df_teams_home, df_teams_away))
df_teams.drop_duplicates()
# Out:
#              date             home_team         away_team  home_score  \
# 1      1873-03-08               England          Scotland           4
# 3      1875-03-06               England          Scotland           2
# 6      1877-03-03               England          Scotland           1
# 10     1879-01-18               England             Wales           2
# 11     1879-04-05               England          Scotland           5
# 16     1881-02-26               England             Wales           0
# 17     1881-03-12               England          Scotland           1
# 24     1883-02-03               England             Wales           5
# 25     1883-02-24               England  Northern Ireland           7
# 26     1883-03-10               England          Scotland           2
# 35     1885-02-28               England  Northern Ireland           4
# 36     1885-03-14               England             Wales           1
# 38     1885-03-21               England          Scotland           1
# 49     1887-02-05               England  Northern Ireland           7
# 51     1887-02-26               England             Wales           4
# 53     1887-03-19               England          Scotland           2
# 62     1889-02-23               England             Wales           4
# 63     1889-03-02               England  Northern Ireland           6
# 65     1889-04-13               England          Scotland           2
# 75     1891-03-07               England             Wales           4
# 76     1891-03-07               England  Northern Ireland           6
# 85     1893-02-25               England  Northern Ireland           6
# 86     1893-03-13               England             Wales           6
# 89     1893-04-01               England          Scotland           5
# 96     1895-03-09               England  Northern Ireland           9
# 98     1895-03-18               England             Wales           1
# 101    1895-04-06               England          Scotland           3
# 108    1897-02-20               England  Northern Ireland           6
# 112    1897-03-29               England             Wales           4
# 113    1897-04-03               England          Scotland           1
# ...           ...                   ...               ...         ...
# 38639  2017-11-13                 Italy            Sweden           0
# 38644  2017-11-13              Bulgaria      Saudi Arabia           1
# 38661  2017-11-14               Ireland           Denmark           1
# 38663  2017-11-14               Hungary        Costa Rica           1
# 38667  2017-11-14                 China          Colombia           0
# 38669  2017-11-14                 Qatar           Iceland           1
# 38671  2017-11-14                 Wales            Panama           1
# 38673  2017-11-14               Austria           Uruguay           2
# 38722  2017-12-12             Korea DPR    Korea Republic           0
# 38736  2017-12-22                Kuwait      Saudi Arabia           1
# 38740  2017-12-25  United Arab Emirates      Saudi Arabia           0
# 38752  2018-01-07               Estonia            Sweden           1
# 38755  2018-01-11             Indonesia           Iceland           0
# 38756  2018-01-14             Indonesia           Iceland           1
# 38757  2018-01-27               Moldova    Korea Republic           0
# 38759  2018-01-30               Jamaica    Korea Republic           2
# 38762  2018-02-03                Latvia    Korea Republic           0
# 38764  2018-02-28                  Iraq      Saudi Arabia           4
# 38791  2018-03-23           Netherlands           England           0
# 38794  2018-03-23                 Italy         Argentina           0
# 38795  2018-03-23                Norway         Australia           4
# 38796  2018-03-23                Greece       Switzerland           0
# 38803  2018-03-23               Ukraine      Saudi Arabia           1
# 38809  2018-03-23              Scotland        Costa Rica           0
# 38825  2018-03-24      Northern Ireland    Korea Republic           2
# 38851  2018-03-26                 Wales           Uruguay           0
# 38867  2018-03-27                Greece             Egypt           1
# 38877  2018-03-27               Ukraine             Japan           2
# 38880  2018-03-27               Romania            Sweden           1
# 38881  2018-03-27    Bosnia-Herzegovina           Senegal           0
#
#        away_score                    tournament            city  \
# 1               2                      Friendly          London
# 3               2                      Friendly          London
# 6               3                      Friendly          London
# 10              1                      Friendly          London
# 11              4                      Friendly          London
# 16              1                      Friendly       Blackburn
# 17              6                      Friendly          London
# 24              0                      Friendly          London
# 25              0                      Friendly       Liverpool
# 26              3                      Friendly       Sheffield
# 35              0          British Championship      Manchester
# 36              1          British Championship       Blackburn
# 38              1          British Championship          London
# 49              0          British Championship       Sheffield
# 51              0          British Championship          London
# 53              3          British Championship       Blackburn
# 62              1          British Championship  Stoke-on-Trent
# 63              1          British Championship       Liverpool
# 65              3          British Championship          London
# 75              1          British Championship      Sunderland
# 76              1          British Championship   Wolverhampton
# 85              1          British Championship      Birmingham
# 86              0          British Championship  Stoke-on-Trent
# 89              2          British Championship        Richmond
# 96              0          British Championship           Derby
# 98              1          British Championship          London
# 101             0          British Championship       Liverpool
# 108             0          British Championship      Nottingham
# 112             0          British Championship       Sheffield
# 113             2          British Championship          London
# ...           ...                           ...             ...
# 38639           0  FIFA World Cup qualification           Milan
# 38644           0                      Friendly          Lisbon
# 38661           5  FIFA World Cup qualification          Dublin
# 38663           0                      Friendly        Budapest
# 38667           4                      Friendly       Chongqing
# 38669           1                      Friendly            Doha
# 38671           1                      Friendly         Cardiff
# 38673           1                      Friendly          Vienna
# 38722           1             EAFF Championship           Chōfu
# 38736           2                      Friendly          Kuwait
# 38740           0                      Friendly          Kuwait
# 38752           1                      Friendly       Abu Dhabi
# 38755           6                      Friendly          Sleman
# 38756           4                      Friendly         Jakarta
# 38757           1                      Friendly         Antalya
# 38759           2                      Friendly         Antalya
# 38762           1                      Friendly         Antalya
# 38764           1                      Friendly           Basra
# 38791           1                      Friendly       Amsterdam
# 38794           2                      Friendly      Manchester
# 38795           1                      Friendly            Oslo
# 38796           1                      Friendly          Athens
# 38803           1                      Friendly        Marbella
# 38809           1                      Friendly         Glasgow
# 38825           1                      Friendly         Belfast
# 38851           1                      Friendly         Nanning
# 38867           0                      Friendly          Zurich
# 38877           1                      Friendly           Liège
# 38880           0                      Friendly         Craiova
# 38881           0                      Friendly        Le Havre
#
#                     country      winning_team  goal_difference
# 1                   England           England                2
# 3                   England               Tie                0
# 6                   England          Scotland                2
# 10                  England           England                1
# 11                  England           England                1
# 16                  England             Wales                1
# 17                  England          Scotland                5
# 24                  England           England                5
# 25                  England           England                7
# 26                  England          Scotland                1
# 35                  England           England                4
# 36                  England               Tie                0
# 38                  England               Tie                0
# 49                  England           England                7
# 51                  England           England                4
# 53                  England          Scotland                1
# 62                  England           England                3
# 63                  England           England                5
# 65                  England          Scotland                1
# 75                  England           England                3
# 76                  England           England                5
# 85                  England           England                5
# 86                  England           England                6
# 89                  England           England                3
# 96                  England           England                9
# 98                  England               Tie                0
# 101                 England           England                3
# 108                 England           England                6
# 112                 England           England                4
# 113                 England          Scotland                1
# ...                     ...               ...              ...
# 38639                 Italy               Tie                0
# 38644              Portugal          Bulgaria                1
# 38661               Ireland           Denmark                4
# 38663               Hungary           Hungary                1
# 38667                 China          Colombia                4
# 38669                 Qatar               Tie                0
# 38671                 Wales               Tie                0
# 38673               Austria           Austria                1
# 38722                 Japan    Korea Republic                1
# 38736                Kuwait      Saudi Arabia                1
# 38740                Kuwait               Tie                0
# 38752  United Arab Emirates               Tie                0
# 38755             Indonesia           Iceland                6
# 38756             Indonesia           Iceland                3
# 38757                Turkey    Korea Republic                1
# 38759                Turkey               Tie                0
# 38762                Turkey    Korea Republic                1
# 38764                  Iraq              Iraq                3
# 38791           Netherlands           England                1
# 38794               England         Argentina                2
# 38795                Norway            Norway                3
# 38796                Greece       Switzerland                1
# 38803                 Spain               Tie                0
# 38809              Scotland        Costa Rica                1
# 38825      Northern Ireland  Northern Ireland                1
# 38851                 China           Uruguay                1
# 38867           Switzerland            Greece                1
# 38877               Belgium           Ukraine                1
# 38880               Romania           Romania                1
# 38881                France               Tie                0
#
# [16720 rows x 10 columns]

# %% [markdown]
# ##### As mentioned earlier, slicing our data from 1930 onwards, due to limitation of elo ranking dataset

# %%
# Loop for creating a new column 'year'
year = []
for row in df_teams['date']:
    year.append(int(row[:4]))
df_teams['match_year'] = year

# Slicing the dataset to see how many matches took place from 1930 onwards (the year of the first ever World Cup)
df_teams30 = df_teams[df_teams.match_year >= 1930]
df_teams30.head()
# Out:
#             date home_team       away_team  home_score  away_score tournament  \
# 1230  1930-01-01     Spain  Czechoslovakia           1           0   Friendly
# 1231  1930-01-12  Portugal  Czechoslovakia           1           0   Friendly
# 1237  1930-02-23  Portugal          France           2           0   Friendly
# 1238  1930-03-02   Germany           Italy           0           2   Friendly
# 1240  1930-03-23    France     Switzerland           3           3   Friendly
#
#                    city   country winning_team  goal_difference  match_year
# 1230          Barcelona     Spain        Spain                1        1930
# 1231             Lisbon  Portugal     Portugal                1        1930
# 1237              Porto  Portugal     Portugal                2        1930
# 1238  Frankfurt am Main   Germany        Italy                2        1930
# 1240           Colombes    France          Tie                0        1930

# %% [markdown]
# ##### Dropping unused column to reduce dimension needed for training (Speed up training)

# %%
df_teams30 = df_teams30.drop(['date', 'home_score', 'away_score', 'tournament', 'city', 'country', 'goal_difference', 'match_year'], axis=1)
df_teams30.head(5)
# Out:
#      home_team       away_team winning_team
# 1230     Spain  Czechoslovakia        Spain
# 1231  Portugal  Czechoslovakia     Portugal
# 1237  Portugal          France     Portugal
# 1238   Germany           Italy        Italy
# 1240    France     Switzerland          Tie

# %% [markdown]
# ##### Map ELO rating based on team name, a major mistake made during the collection of ELO rating <br>(Only qualifier data was collected, in order to have a balance historical view even for teams that did not make it to the qualifiers we only took 2018 rating for missing countries)

# %%
# Read .csv files from elo rating
elorating = pd.read_csv('datasets/EloRating.csv', encoding = 'ISO-8859-1')

ELODict={}
for index, row in elorating.iterrows():
    ELODict[row["Team"]]= row["Rating"]

# map rating information into our dataframe    
df_teams30['home_team_rating']=df_teams30['home_team'].map(ELODict)
df_teams30['away_team_rating']=df_teams30['away_team'].map(ELODict)
df_teams30['rating_diff'] = df_teams30['home_team_rating'] - df_teams30['away_team_rating']
df_teams30['rating_diff'] = df_teams30['rating_diff'].astype('int')

df_teams30.head()
# Out:
#      home_team       away_team winning_team  home_team_rating  \
# 1230     Spain  Czechoslovakia        Spain              2038
# 1231  Portugal  Czechoslovakia     Portugal              1976
# 1237  Portugal          France     Portugal              1976
# 1238   Germany           Italy        Italy              2077
# 1240    France     Switzerland          Tie              1999
#
#       away_team_rating  rating_diff
# 1230              1882          156
# 1231              1882           94
# 1237              1999          -23
# 1238              1850          227
# 1240              1890          109

# %% [markdown]
# ## 2) Building our ML Model
# Before building the model, we split the data into x,y (X variable like home vs away pair and Y variable who wins)<br>
# probably should convert Y into 1 hot vector to avoid bias<br>
# Also swap out X variable of country name into ID via hashmap (Keras Input limitation)

# %%
# rename winning team string as integer
df_teams30 = df_teams30.reset_index(drop=True)
df_teams30.loc[df_teams30.winning_team == df_teams30.home_team, 'winning_team']= 0
df_teams30.loc[df_teams30.winning_team == 'Tie', 'winning_team']= 2
df_teams30.loc[df_teams30.winning_team == df_teams30.away_team, 'winning_team']= 1 
df_teams30.head()
# Out:
#   home_team       away_team winning_team  home_team_rating  away_team_rating  \
# 0     Spain  Czechoslovakia            0              2038              1882
# 1  Portugal  Czechoslovakia            0              1976              1882
# 2  Portugal          France            0              1976              1999
# 3   Germany           Italy            1              2077              1850
# 4    France     Switzerland            2              1999              1890
#
#    rating_diff
# 0          156
# 1           94
# 2          -23
# 3          227
# 4          109

# %%
# convert all teams into unique ID via dictionary
finalX = df_teams30['home_team'].append(df_teams30['away_team'])
CountryDict = dict([(y,x+1) for x,y in enumerate(sorted(set(finalX)))])      
df_teams30["home_team"].replace(CountryDict, inplace=True)
df_teams30["away_team"].replace(CountryDict, inplace=True)

# Separate X and y sets
X = df_teams30.drop(['winning_team'], axis=1)
y = df_teams30["winning_team"]
y = y.astype('int')

# Separate train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42, shuffle=True)

# 1 hotvectorisation of our Y column to avoid bias (Also for model to predict category)
y_test_1hot = to_categorical(y_test).astype(np.int)
y_train_1hot = to_categorical(y_train).astype(np.int)

# %% [markdown]
# ##### basic logistic regression

# %%
from sklearn.linear_model import LogisticRegression

logreg = LogisticRegression()
logreg.fit(X_train, y_train)
score = logreg.score(X_train, y_train)
score2 = logreg.score(X_test, y_test)

print("Training set accuracy: ", '%.3f'%(score))
print("Test set accuracy: ", '%.3f'%(score2))
# Out:
# Training set accuracy:  0.536
# Test set accuracy:  0.541

# %% [markdown]
# ##### Noticed model is only 50+% accuracy which is pretty low, slightly better than guessing even after using elo ranking dataset as briefly mentioned above to improve our model accuracy instead of just country ID

# %% [markdown]
# ##### AlternatIve model in keras
# Current stack consist input layer with 5 dimension (with elorating for away and home team)<br>
# Next dense fully connected dense layers with built in activation relu<br>
# Finally softmax to squash output prediction as probability between representing win, draw or tie

# %%
### define and fit the final model
model = Sequential()
model.add(Dense(32, input_dim=5, activation='relu'))
# add noise to model to avoid bais
model.add(Dropout(0.2))
model.add(Dense(64, activation='relu',kernel_initializer='normal'))
model.add(Dense(128, activation='relu',kernel_initializer='normal'))
model.add(Dense(64, activation='relu',kernel_initializer='normal'))
model.add(Dense(32, activation='relu',kernel_initializer='normal'))
#model.add(Dense(3))
# squash result as probability
model.add(Dense(3, activation='softmax'))


#optimisation to converge faster
#epsilon so that division is not 0 think of it as bias recommended 10^-8
#rmsprop = RMSprop(lr=0.001, rho=0.9, epsilon=1e-08, decay=0.0)
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['categorical_accuracy'])



# toggle verbose to print text
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=20, verbose=0,batch_size=32)
#model.fit(X_train, y_train_1hot, validation_data=(X_test,y_test_1hot), epochs=1000, verbose=0)

# %%
# backup our model
model.save('model/my_model_current.h5')

# show summary of model
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 32)                192
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                2112
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               8320
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_5 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_6 (Dense)              (None, 3)                 99
# =================================================================
# Total params: 21,059
# Trainable params: 21,059
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ##### Noticed we only have 50+ % accuracy not very good for a ML model which should at least hit 70. We will be including elo ranking dataset as briefly mentioned above to improve our model accuracy

# %%
scores = model.evaluate(X_train, y_train, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))

#print(y_test)
# sampling our model prediction
test_sample=np.array([145,183,1902,1795,178]).reshape(1,5)
# predict output index 
sample_output=model.predict_classes(test_sample)
print(sample_output)

#import numpy
#from numpy import unravel_index
#numpy.set_printoptions(threshold=numpy.nan)
# result verification

#y_pred_probability = model.predict_proba(X_test)
#y_pred = model.predict_classes(X_test)

#print(y_pred)

#predictions = numpy.argmax(model.predict(X_test), axis=1)
#for i in range(1000):
#    print(predictions[i])
#plt.scatter(X_test['home_team'], y_pred)
#plt.show()
# Out:
# categorical_accuracy: 70.76%
# [0]

# %% [markdown]
# ## 3) Creating prediction sets from current 2018 data
# before final prediction we will have to clean up the dataset and merge accordingly

# %%
# Loading new datasets
ranking = pd.read_csv('datasets/fifa_rankings.csv') # Obtained from https://us.soccerway.com/teams/rankings/fifa/?ICID=TN_03_05_01
fixtures = pd.read_csv('datasets/fixtures.csv') # Obtained from https://fixturedownload.com/results/fifa-world-cup-2018

# List for storing the group stage games
pred_set = []

# %% [markdown]
# ##### include fix ranking within our 2018 group stage fixture further sort by ranking

# %%
# Create new columns with ranking position of each team
fixtures.insert(1, 'first_position', fixtures['Home Team'].map(ranking.set_index('Team')['Position']))
fixtures.insert(2, 'second_position', fixtures['Away Team'].map(ranking.set_index('Team')['Position']))

# We only need the group stage games, so we have to slice the dataset
# the slice can be read as get till row 48 for all columns
fixtures = fixtures.iloc[:48, :]
fixtures.tail()
# Out:
#    Round Number  first_position  second_position              Date  \
# 43            3             6.0             25.0  27/06/2018 21:00
# 44            3            60.0             10.0  28/06/2018 17:00
# 45            3            28.0             16.0  28/06/2018 17:00
# 46            3            55.0             14.0  28/06/2018 21:00
# 47            3            13.0              3.0  28/06/2018 21:00
#
#                    Location    Home Team   Away Team    Group  Result
# 43  Nizhny Novgorod Stadium  Switzerland  Costa Rica  Group E     NaN
# 44        Volgograd Stadium        Japan      Poland  Group H     NaN
# 45           Samara Stadium      Senegal    Colombia  Group H     NaN
# 46          Saransk Stadium       Panama     Tunisia  Group G     NaN
# 47      Kaliningrad Stadium      England     Belgium  Group G     NaN

# %% [markdown]
# ##### predicting which team proceeds to next stage

# %%
# Loop to add teams to new prediction dataset based on the ranking position of each team# Loop  
for index, row in fixtures.iterrows():
    if row['first_position'] < row['second_position']:
        pred_set.append({'home_team': row['Home Team'], 'away_team': row['Away Team'], 'winning_team': None})
    else:
        pred_set.append({'home_team': row['Away Team'], 'away_team': row['Home Team'], 'winning_team': None})
        
pred_set = pd.DataFrame(pred_set)
backup_pred_set = pred_set

pred_set.head()
# Out:
#       away_team home_team winning_team
# 0  Saudi Arabia    Russia         None
# 1         Egypt   Uruguay         None
# 2       Morocco      Iran         None
# 3         Spain  Portugal         None
# 4     Australia    France         None

# %% [markdown]
# ## 4)  Deploy Model
# Prepare match pairs from fixtures dataset (feed in eloranking from our dictionary)<br>
# Using our previously trained model to predict outcome

# %%
#load our previously trained model
model = load_model('model/my_model_current.h5')

# convert our group stage data into tuples
groupstage=pred_set.drop(['winning_team'], axis=1)
groupstagetuples = [tuple(x) for x in groupstage.values]


def prepare_predict(matches):
    
    wc_x_pred = []
    # data preprocessing
    for matchPairs in matches:
        home_team_id = CountryDict[matchPairs[0]]
        away_team_id = CountryDict[matchPairs[1]]
        home_team_elorating = ELODict[matchPairs[0]]
        away_team_elorating = ELODict[matchPairs[1]]
        elodifference = ELODict[matchPairs[0]]-ELODict[matchPairs[1]]
        
        # transform array
        matchset = [home_team_id, away_team_id, home_team_elorating, away_team_elorating, elodifference]
        wc_x_pred.append(matchset)
    
    # convert prediction set into numpy array
    wc_x_pred = np.array(wc_x_pred)
    
    # return y_prediction probability
    wc_y_pred = model.predict_proba(wc_x_pred)
    # iterate results
    for index, outcome in enumerate(wc_y_pred):
        outcome_win = str(outcome[0])
        outcome_draw = str(outcome[2])
        outcome_lose = str(outcome[1])
        outcome_final = np.where(outcome == outcome.max())
        
        
        print('Probability of ' + matches[index][0]+ ' winning: ' + outcome_win)
        print('Probability of Tie: '+ outcome_draw) 
        print('Probability of ' + matches[index][1] + ' winning: ' + outcome_lose)
        if(outcome_final[0]==0):
            print("Final Winner: "+ matches[index][0])
        elif(outcome_final[0]==1):
            print("Final Winner: "+ matches[index][1])
        else:
            print("Draw")
        print("\n")
        
    
prepare_predict(groupstagetuples)
# Out:
# Probability of Saudi Arabia winning: 0.3777896
# Probability of Tie: 0.28834853
# Probability of Russia winning: 0.3338619
# Final Winner: Saudi Arabia
#
#
# Probability of Egypt winning: 0.259684
# Probability of Tie: 0.25883275
# Probability of Uruguay winning: 0.48148325
# Final Winner: Uruguay
#
#
# Probability of Morocco winning: 0.38790226
# Probability of Tie: 0.2882633
# Probability of Iran winning: 0.3238345
# Final Winner: Morocco
#
#
# Probability of Spain winning: 0.48158658
# Probability of Tie: 0.27462465
# Probability of Portugal winning: 0.24378887
# Final Winner: Spain
#
#
# Probability of Australia winning: 0.26497513
# Probability of Tie: 0.26096773
# Probability of France winning: 0.47405714
# Final Winner: France
#
#
# Probability of Iceland winning: 0.3103413
# Probability of Tie: 0.27836928
# Probability of Argentina winning: 0.4112895
# Final Winner: Argentina
#
#
# Probability of Denmark winning: 0.47184268
# Probability of Tie: 0.27724323
# Probability of Peru winning: 0.25091413
# Final Winner: Denmark
#
#
# Probability of Nigeria winning: 0.28768736
# Probability of Tie: 0.27051383
# Probability of Croatia winning: 0.4417988
# Final Winner: Croatia
#
#
# Probability of Serbia winning: 0.4920228
# Probability of Tie: 0.27078027
# Probability of Costa Rica winning: 0.2371969
# Final Winner: Serbia
#
#
# Probability of Mexico winning: 0.29663065
# Probability of Tie: 0.27378878
# Probability of Germany winning: 0.42958054
# Final Winner: Germany
#
#
# Probability of Switzerland winning: 0.26581636
# Probability of Tie: 0.26171905
# Probability of Brazil winning: 0.4724646
# Final Winner: Brazil
#
#
# Probability of Korea Republic winning: 0.43686408
# Probability of Tie: 0.2900527
# Probability of Sweden winning: 0.27308318
# Final Winner: Korea Republic
#
#
# Probability of Panama winning: 0.22755556
# Probability of Tie: 0.24366198
# Probability of Belgium winning: 0.52878255
# Final Winner: Belgium
#
#
# Probability of Tunisia winning: 0.22620603
# Probability of Tie: 0.24311432
# Probability of England winning: 0.5306797
# Final Winner: England
#
#
# Probability of Japan winning: 0.27294856
# Probability of Tie: 0.26455274
# Probability of Colombia winning: 0.46249875
# Final Winner: Colombia
#
#
# Probability of Senegal winning: 0.44185433
# Probability of Tie: 0.2899237
# Probability of Poland winning: 0.268222
# Final Winner: Senegal
#
#
# Probability of Russia winning: 0.4851972
# Probability of Tie: 0.27315244
# Probability of Egypt winning: 0.24165042
# Final Winner: Russia
#
#
# Probability of Morocco winning: 0.26299116
# Probability of Tie: 0.2604758
# Probability of Portugal winning: 0.47653303
# Final Winner: Portugal
#
#
# Probability of Saudi Arabia winning: 0.20976102
# Probability of Tie: 0.23430078
# Probability of Uruguay winning: 0.55593824
# Final Winner: Uruguay
#
#
# Probability of Iran winning: 0.30487898
# Probability of Tie: 0.27650943
# Probability of Spain winning: 0.4186116
# Final Winner: Spain
#
#
# Probability of Australia winning: 0.3200373
# Probability of Tie: 0.2812767
# Probability of Denmark winning: 0.39868602
# Final Winner: Denmark
#
#
# Probability of Peru winning: 0.37191635
# Probability of Tie: 0.2882445
# Probability of France winning: 0.3398392
# Final Winner: Peru
#
#
# Probability of Croatia winning: 0.35332048
# Probability of Tie: 0.28874686
# Probability of Argentina winning: 0.35793266
# Final Winner: Argentina
#
#
# Probability of Costa Rica winning: 0.15806594
# Probability of Tie: 0.20128848
# Probability of Brazil winning: 0.64064556
# Final Winner: Brazil
#
#
# Probability of Nigeria winning: 0.36839703
# Probability of Tie: 0.28844246
# Probability of Iceland winning: 0.34316054
# Final Winner: Nigeria
#
#
# Probability of Serbia winning: 0.44277683
# Probability of Tie: 0.28980654
# Probability of Switzerland winning: 0.26741663
# Final Winner: Serbia
#
#
# Probability of Tunisia winning: 0.22581007
# Probability of Tie: 0.24286777
# Probability of Belgium winning: 0.5313222
# Final Winner: Belgium
#
#
# Probability of Korea Republic winning: 0.35582605
# Probability of Tie: 0.28879353
# Probability of Mexico winning: 0.35538042
# Final Winner: Korea Republic
#
#
# Probability of Sweden winning: 0.24082431
# Probability of Tie: 0.2503865
# Probability of Germany winning: 0.5087892
# Final Winner: Germany
#
#
# Probability of Panama winning: 0.22755837
# Probability of Tie: 0.24369515
# Probability of England winning: 0.52874655
# Final Winner: England
#
#
# Probability of Japan winning: 0.4406785
# Probability of Tie: 0.2899415
# Probability of Senegal winning: 0.26937994
# Final Winner: Japan
#
#
# Probability of Colombia winning: 0.5205618
# Probability of Tie: 0.26070118
# Probability of Poland winning: 0.21873696
# Final Winner: Colombia
#
#
# Probability of Russia winning: 0.34115455
# Probability of Tie: 0.2875513
# Probability of Uruguay winning: 0.3712941
# Final Winner: Uruguay
#
#
# Probability of Saudi Arabia winning: 0.43448478
# Probability of Tie: 0.29032278
# Probability of Egypt winning: 0.27519238
# Final Winner: Saudi Arabia
#
#
# Probability of Iran winning: 0.34153602
# Probability of Tie: 0.28759146
# Probability of Portugal winning: 0.3708726
# Final Winner: Portugal
#
#
# Probability of Morocco winning: 0.21881837
# Probability of Tie: 0.23905218
# Probability of Spain winning: 0.5421294
# Final Winner: Spain
#
#
# Probability of Denmark winning: 0.34723973
# Probability of Tie: 0.28871512
# Probability of France winning: 0.36404514
# Final Winner: France
#
#
# Probability of Australia winning: 0.3341804
# Probability of Tie: 0.2856294
# Probability of Peru winning: 0.3801902
# Final Winner: Peru
#
#
# Probability of Nigeria winning: 0.20709215
# Probability of Tie: 0.23258184
# Probability of Argentina winning: 0.56032604
# Final Winner: Argentina
#
#
# Probability of Iceland winning: 0.36137536
# Probability of Tie: 0.28859589
# Probability of Croatia winning: 0.35002872
# Final Winner: Iceland
#
#
# Probability of Sweden winning: 0.4494182
# Probability of Tie: 0.28791782
# Probability of Mexico winning: 0.26266396
# Final Winner: Sweden
#
#
# Probability of Korea Republic winning: 0.19052188
# Probability of Tie: 0.22274154
# Probability of Germany winning: 0.5867366
# Final Winner: Germany
#
#
# Probability of Serbia winning: 0.19574682
# Probability of Tie: 0.2260141
# Probability of Brazil winning: 0.57823914
# Final Winner: Brazil
#
#
# Probability of Costa Rica winning: 0.33150244
# Probability of Tie: 0.28487927
# Probability of Switzerland winning: 0.38361832
# Final Winner: Switzerland
#
#
# Probability of Japan winning: 0.35352722
# Probability of Tie: 0.288838
# Probability of Poland winning: 0.35763472
# Final Winner: Poland
#
#
# Probability of Senegal winning: 0.32771993
# Probability of Tie: 0.2839683
# Probability of Colombia winning: 0.3883118
# Final Winner: Colombia
#
#
# Probability of Panama winning: 0.45787457
# Probability of Tie: 0.28458107
# Probability of Tunisia winning: 0.25754443
# Final Winner: Panama
#
#
# Probability of England winning: 0.475737
# Probability of Tie: 0.27600247
# Probability of Belgium winning: 0.2482606
# Final Winner: England

# %% [markdown]
# ##### hardcoded the group stage tuple all the way to the finals, this sort of flexibility instead of code driven function allows us to modify who proceed to quater finals so on and so forth based on actual results (Ideally, our model should predict the outcode for every match correctly but hey nothing is perfect right?)
#
# Note: Replaced some of the wrongly predicted outcomes argentina with respective country<Br>
# **Group knockoff**:<br>
# 1A vs 2B<br>
# 1C vs 2D<br>
# 1E vs 2F<br>
# 1G vs 2H<br>
# <br>
# 1B vs 2A<br>
# 1D vs 2C<br>
# 1F vs 2E<br>
# 1H vs 2G<br>

# %%
# List of tuples before we arrange the teams in home and away
group_16 = [('Uruguay', 'Portugal'),
            ('France', 'Argentina'),
            ('Brazil', 'Germany'),
            ('Belgium', 'Japan'),
            ('Spain', 'Russia'),
            ('Croatia', 'Denmark'),
            ('Mexico', 'Switzerland'),
            ('Senegal', 'England')]

# %% [markdown]
# ##### Function to clean tuple dataset from fixture and order by ranking (A not so nice approach to give higher ranking teams as homedue to higher win rate)

# %%
# actual run
prepare_predict(group_16)
# Out:
# Probability of Uruguay winning: 0.44903073
# Probability of Tie: 0.28807977
# Probability of Portugal winning: 0.26288947
# Final Winner: Uruguay
#
#
# Probability of France winning: 0.48491195
# Probability of Tie: 0.27295083
# Probability of Argentina winning: 0.24213725
# Final Winner: France
#
#
# Probability of Brazil winning: 0.51013225
# Probability of Tie: 0.26428628
# Probability of Germany winning: 0.22558145
# Final Winner: Brazil
#
#
# Probability of Belgium winning: 0.6177788
# Probability of Tie: 0.22252059
# Probability of Japan winning: 0.15970063
# Final Winner: Belgium
#
#
# Probability of Spain winning: 0.6461022
# Probability of Tie: 0.21068195
# Probability of Russia winning: 0.14321584
# Final Winner: Spain
#
#
# Probability of Croatia winning: 0.4617924
# Probability of Tie: 0.28146687
# Probability of Denmark winning: 0.25674075
# Final Winner: Croatia
#
#
# Probability of Mexico winning: 0.45148328
# Probability of Tie: 0.28707248
# Probability of Switzerland winning: 0.26144427
# Final Winner: Mexico
#
#
# Probability of Senegal winning: 0.31567955
# Probability of Tie: 0.280378
# Probability of England winning: 0.40394253
# Final Winner: England

# %% [markdown]
# ##### based on previous result proceed

# %%
# List of matches
quarters = [('Uruguay', 'France'),
            ('Brazil', 'Belgium'),
            ('Spain', 'Croatia'),
            ('Mexico', 'England')]

# %%
prepare_predict(quarters)
# Out:
# Probability of Uruguay winning: 0.43582198
# Probability of Tie: 0.29039332
# Probability of France winning: 0.27378476
# Final Winner: Uruguay
#
#
# Probability of Brazil winning: 0.58410466
# Probability of Tie: 0.23638967
# Probability of Belgium winning: 0.17950565
# Final Winner: Brazil
#
#
# Probability of Spain winning: 0.5283174
# Probability of Tie: 0.25785416
# Probability of Croatia winning: 0.21382849
# Final Winner: Spain
#
#
# Probability of Mexico winning: 0.38348788
# Probability of Tie: 0.28775227
# Probability of England winning: 0.32875988
# Final Winner: Mexico

# %%
# List of matches
semi = [('Uruguay', 'Brazil'),
        ('Spain', 'Mexico')]

# %%
prepare_predict(semi)
# Out:
# Probability of Uruguay winning: 0.27910528
# Probability of Tie: 0.26725912
# Probability of Brazil winning: 0.4536356
# Final Winner: Brazil
#
#
# Probability of Spain winning: 0.54798007
# Probability of Tie: 0.25092888
# Probability of Mexico winning: 0.20109102
# Final Winner: Spain

# %%
# List of matches
losersfinals = [('Uruguay', 'Mexico')]

# %%
prepare_predict(losersfinals)
# Out:
# Probability of Uruguay winning: 0.4739217
# Probability of Tie: 0.2778399
# Probability of Mexico winning: 0.24823843
# Final Winner: Uruguay

# %%
# The final game# The big 
finals = [('Brazil', 'Spain')]

# %%
prepare_predict(finals)
# Out:
# Probability of Brazil winning: 0.53221256
# Probability of Tie: 0.25645423
# Probability of Spain winning: 0.2113332
# Final Winner: Brazil

# %% [markdown]
# ## 5) FIFA 2018 Score Prediction
#
# Using simple linear regression to predict the Total Goals for the Final/SemiFinal Match<br>
# After which a difference of winner loser linear regression is used based on the predicted Total Goals to retrieve the end result<br>
# For more detail please refer to: 2018 world cup score prediction/(Total)<br>
#
# <img style="margin-left: 0;" src="images/3rd place.jpg">
# **The predicted Score for the 3rd place playoff: 4-3**
#
#
# <img style="margin-left: 0;" src="images/Final Score.jpg">
# **The predicted Score for the Finals: 2-1**

# %% [markdown]
# ## 6) Project Review
# **The experiments**:<br>
# Elo rating did improve prediction from 50~% to 70~%<br>
# found that LSTM model would not help with model converging<br>
# the score prediction was separated out from winners and losers to avoid dependancies
#
# **For future work**:<br>
# Improve handling of draw to proceed in matches after group stage<br>
# Also ranking could be used for training and not just sorting teams between home and away<br>
# Finally, betting historic data would have been helpful<br>
#
# **Limitation**<br>
# The limitation of this model would be the inability to predict score but instead predicting win or lose<br>
# A separate linear regression algorithm would be use to predict the score instead
#
# **Results**<br>
# 1st Brazil, 2nd Spain, 3rd Uruguay<br>
# Final Match: 2-1<br>
# Losers Final: 4-3

# %% [markdown]
# ## 7) References
# https://machinelearningmastery.com/evaluate-performance-deep-learning-models-keras/<br>
# https://medium.com/@siavash_37715/how-to-predict-bitcoin-and-ethereum-price-with-rnn-lstm-in-keras-a6d8ee8a5109<br>
# https://towardsdatascience.com/using-lstms-to-forecast-time-series-4ab688386b1f<br>
# https://github.com/charliechurches/Russia_World_Cup_Prediction/blob/master/Russia_World_Cup_predict.ipynb<br>
# https://www.eloratings.net/<br>
# https://www.youtube.com/watch?v=Cltt47Ah3Q4
